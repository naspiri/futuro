# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.options.display.max_columns = 30

# %%
df = pd.read_csv('/Users/marco/Desktop/futuro/full.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  WikiId  \
# 0      0         A/5 21171   7.2500   NaN        S   691.0
# 1      0          PC 17599  71.2833   C85        C    90.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S   865.0
# 3      0            113803  53.1000  C123        S   127.0
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'WikiId', 'Name_wiki',
#        'Age_wiki', 'Hometown', 'Boarded', 'Destination', 'Lifeboat', 'Body',
#        'Class'],
#       dtype='object')

# %%
df = df.drop(['WikiId', 'Name_wiki', 'Age_wiki', 'Cabin', 'Ticket', 'Body', 'Lifeboat', 'Class'], axis=1)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked                            Hometown      Boarded  \
# 0      0   7.2500        S          Bridgerule, Devon, England  Southampton
# 1      0  71.2833        C              New York, New York, US    Cherbourg
# 2      0   7.9250        S                  Jyväskylä, Finland  Southampton
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Fare         1308 non-null   float64
#  9   Embarked     1307 non-null   object
#  10  Hometown     1304 non-null   object
#  11  Boarded      1304 non-null   object
#  12  Destination  1304 non-null   object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 133.1+ KB

# %%
df.loc[df['Name'].str.contains('Astor', case=False)]
# Out:
#       PassengerId  Survived  Pclass  \
# 700           701       1.0       1
# 1093         1094       NaN       1
#
#                                                    Name     Sex   Age  SibSp  \
# 700   Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.0      1
# 1093                             Astor, Col. John Jacob    male  47.0      1
#
#       Parch     Fare Embarked                Hometown    Boarded  \
# 700       0  227.525        C  New York, New York, US  Cherbourg
# 1093      0  227.525        C  New York, New York, US  Cherbourg
#
#                  Destination
# 700   New York, New York, US
# 1093  New York, New York, US

# %%
df.loc[1093, 'Survived']=0.0

# %%
df.loc[df['Name'].str.contains('Astor', case=False)]
# Out:
#       PassengerId  Survived  Pclass  \
# 700           701       1.0       1
# 1093         1094       0.0       1
#
#                                                    Name     Sex   Age  SibSp  \
# 700   Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.0      1
# 1093                             Astor, Col. John Jacob    male  47.0      1
#
#       Parch     Fare Embarked                Hometown    Boarded  \
# 700       0  227.525        C  New York, New York, US  Cherbourg
# 1093      0  227.525        C  New York, New York, US  Cherbourg
#
#                  Destination
# 700   New York, New York, US
# 1093  New York, New York, US

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     892 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Fare         1308 non-null   float64
#  9   Embarked     1307 non-null   object
#  10  Hometown     1304 non-null   object
#  11  Boarded      1304 non-null   object
#  12  Destination  1304 non-null   object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 133.1+ KB

# %%
df.loc[df['Hometown'].isnull()]
# Out:
#       PassengerId  Survived  Pclass  \
# 347           348       1.0       3
# 557           558       0.0       1
# 1041         1042       NaN       1
# 1048         1049       NaN       3
# 1228         1229       NaN       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 347   Davison, Mrs. Thomas Henry (Mary E Finck)  female   NaN      1      0
# 557                         Robbins, Mr. Victor    male   NaN      0      0
# 1041      Earnshaw, Mrs. Boulton (Olive Potter)  female  23.0      0      1
# 1048                   Lundin, Miss. Olga Elida  female  23.0      0      0
# 1228                          Elias, Mr. Joseph    male  39.0      0      2
#
#           Fare Embarked Hometown Boarded Destination
# 347    16.1000        S      NaN     NaN         NaN
# 557   227.5250        C      NaN     NaN         NaN
# 1041   83.1583        C      NaN     NaN         NaN
# 1048    7.8542        S      NaN     NaN         NaN
# ...

# %%
df.loc[df['Name'].str.contains('Davison', case=False)]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 347          348       1.0       3  Davison, Mrs. Thomas Henry (Mary E Finck)
# 949          950       NaN       3                  Davison, Mr. Thomas Henry
#
#         Sex  Age  SibSp  Parch  Fare Embarked                        Hometown  \
# 347  female  NaN      1      0  16.1        S                             NaN
# 949    male  NaN      1      0  16.1        S  Liverpool, Merseyside, England
#
#          Boarded           Destination
# 347          NaN                   NaN
# 949  Southampton  Bedford, Indiana, US

# %%
df.loc[347,'Boarded']=df.loc[949,'Boarded']

# %%
df.loc[347,'Destination']=df.loc[949,'Destination']

# %%
df.loc[949,'Survived']=0.0

# %%
df.loc[df['Boarded'].isnull()]
# Out:
#       PassengerId  Survived  Pclass                                   Name  \
# 557           558       0.0       1                    Robbins, Mr. Victor
# 1041         1042       NaN       1  Earnshaw, Mrs. Boulton (Olive Potter)
# 1048         1049       NaN       3               Lundin, Miss. Olga Elida
# 1228         1229       NaN       3                      Elias, Mr. Joseph
#
#          Sex   Age  SibSp  Parch      Fare Embarked Hometown Boarded  \
# 557     male   NaN      0      0  227.5250        C      NaN     NaN
# 1041  female  23.0      0      1   83.1583        C      NaN     NaN
# 1048  female  23.0      0      0    7.8542        S      NaN     NaN
# 1228    male  39.0      0      2    7.2292        C      NaN     NaN
#
#      Destination
# 557          NaN
# 1041         NaN
# 1048         NaN
# 1228         NaN

# %%
df.loc[1048,'Boarded']='Southampton'

# %%
df.loc[557,'Boarded']='Cherbourg'

# %%
df.loc[1041,'Boarded']='Cherbourg'

# %%
df.loc[1228,'Boarded']='Cherbourg'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     893 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Fare         1308 non-null   float64
#  9   Embarked     1307 non-null   object
#  10  Hometown     1304 non-null   object
#  11  Boarded      1309 non-null   object
#  12  Destination  1305 non-null   object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 133.1+ KB

# %%
df.loc[df['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62       1.0       1                        Icard, Miss. Amelie
# 829          830       1.0       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Fare Embarked                Hometown  \
# 61   female  38.0      0      0  80.0      NaN  New York, New York, US
# 829  female  62.0      0      0  80.0      NaN  New York, New York, US
#
#          Boarded             Destination
# 61   Southampton  New York, New York, US
# 829  Southampton  New York, New York, US

# %%
df.loc[61,'Embarked']='S'

# %%
df.loc[829,'Embarked']='S'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     893 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Fare         1308 non-null   float64
#  9   Embarked     1309 non-null   object
#  10  Hometown     1304 non-null   object
#  11  Boarded      1309 non-null   object
#  12  Destination  1305 non-null   object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 133.1+ KB

# %%
df.drop(df[df['Survived'].isnull()].index, inplace = True)

# %%
df['Survived']=df['Survived'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 893 entries, 0 to 1093
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  893 non-null    int64
#  1   Survived     893 non-null    int64
#  2   Pclass       893 non-null    int64
#  3   Name         893 non-null    object
#  4   Sex          893 non-null    object
#  5   Age          715 non-null    float64
#  6   SibSp        893 non-null    int64
#  7   Parch        893 non-null    int64
#  8   Fare         893 non-null    float64
#  9   Embarked     893 non-null    object
#  10  Hometown     891 non-null    object
#  11  Boarded      893 non-null    object
#  12  Destination  892 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 97.7+ KB

# %%
df[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 949          950         0       3                 Davison, Mr. Thomas Henry
#
# ...

# %%
df[df['Sex']=='male']['Age'].mean()
# Out:
# 30.762488986784142

# %%
df[df['Sex']=='female']['Age'].mean()
# Out:
# 27.915708812260537

# %%
idx = df[(df['Sex'] == 'male') & df['Age'].isnull()]['Age'].index

# %%
df.loc[idx, 'Age'] = 30.73

# %%
idx = df[(df['Sex'] == 'female') & df['Age'].isnull()]['Age'].index

# %%
df.loc[idx, 'Age'] = 27.92

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 893 entries, 0 to 1093
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  893 non-null    int64
#  1   Survived     893 non-null    int64
#  2   Pclass       893 non-null    int64
#  3   Name         893 non-null    object
#  4   Sex          893 non-null    object
#  5   Age          893 non-null    float64
#  6   SibSp        893 non-null    int64
#  7   Parch        893 non-null    int64
#  8   Fare         893 non-null    float64
#  9   Embarked     893 non-null    object
#  10  Hometown     891 non-null    object
#  11  Boarded      893 non-null    object
#  12  Destination  892 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 130.0+ KB

# %%
df.to_csv('/Users/marco/Desktop/futuro/full.csv')
